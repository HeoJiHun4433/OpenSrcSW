# %%
import matplotlib.pyplot as plt
import csv

f=open('C:\\Users\\Lenovo\\OpenSourceSW\\seoul2.csv', 'r' , encoding='cp949')
f1=open('C:\\Users\\Lenovo\\OpenSourceSW\\seoul2.csv', 'r' , encoding='cp949')
data = csv.reader(f, delimiter=',')
header = next(data)
data1 = csv.reader(f1, delimiter=',')
header1 = next(data1)
result =[]
result1=[]
for row in data:
    if row[-1] != '':
        if row[0].split('-')[1] == '02' and row[0].split('-')[2] =='22' :
            result.append(float(row[-1]))
for row1 in data1:
    if row1[-2] != '':
        if row1[0].split('-')[1] == '02' and row1[0].split('-')[2] =='22' :
            result1.append(float(row1[-2]))

            
print(result) 
print(result1)

plt.plot(result)
plt.plot(result1)
plt.show()
# Out:
# [13.0, 12.1, 4.3, 7.4, 7.0, 4.2, 2.9, 5.4, 10.8, 7.9]
# [0.7, -0.8, -3.1, -2.1, -0.7, -2.2, -0.9, -3.9, -1.6, 0.0]

# %%
import matplotlib.pyplot as plt
import csv

f=open('C:\\Users\\Lenovo\\OpenSourceSW\\seoul2.csv', 'r' , encoding='cp949')
f1=open('C:\\Users\\Lenovo\\OpenSourceSW\\seoul2.csv', 'r' , encoding='cp949')
data = csv.reader(f, delimiter=',')
header = next(data)
data1 = csv.reader(f1, delimiter=',')
header1 = next(data1)
result =[]
result1=[]

for row in data:
    if row[-1] != '':
        if row[0].split('-')[1] =='08':
            result.append(float(row[-1]))
            
for row1 in data1:
    if row1[-1] != '':
        if row1[0].split('-')[1] =='01':
            result1.append(float(row1[-1]))
plt.hist(result)
plt.hist(result1)
plt.show()
